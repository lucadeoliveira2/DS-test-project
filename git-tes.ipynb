# %%
import pandas as pd

# %%
print('merge test. testmerge 2')

# %%
2+15
# Out:
# 17

# %%
print('wow, a new branch, awesome x2')
# Out:
# wow, a new branch

# %%
print('ok, lets see')
# Out:
# ok, lets see
